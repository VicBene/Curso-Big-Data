# %% [markdown]
# ## If - Elif - Else

# %%
#
#    BASICS
a = int(input('Dame el valor de A...'))
b = int(input('Dame el valor de B...'))

if (a == b and b == 1):
  print('A vale B! Y valen 1')
  a=123123
  print(a)
elif (a == b or a == 2):
  print('A vale B o A vale 2')
  if b == 90: 
    print('B vale 90')
  elif b==90:
    print('B vale 99')
  else:
    print('B no es ni 90 ni 99')
elif (a == b):
  print('A vale B!')
    
else:
  print('A no vale B')


print(a, b)
# Out:
# A no vale B
# 3 5

# %%
nombre='Sonia'
if nombre == 'Sonia':
  print('nombre es Sonia')
# Out:
# nombre es Sonia

# %%
#
#     V1
#

# Objetivo: Establecer la tarifa anual para autobuses de Huesca. Dadas las siguientes variables:

#Variables
tarifa = 100
edad = int(input('Dime la edad del cliente...'))
trabaja = int(input('Dame 1 si trabajas. 0 en caso contrario.'))
tarifa_final = 0

#En funcion de edades y trabajo, le aplicare descuentos.

#Descuentos por edad: <=18 --> 25%; >=65 --> 20%
#Descuento por desempleo: 50%
#Descuentos son acumulables

descuento=1

if (edad < 0) or (edad > 150) or ((trabaja != 0) and (trabaja != 1)):
  print('Los datos son erroneos')
else:
  if edad <= 18:
    descuento = descuento*0.75
  elif edad >= 65:
    descuento = descuento*0.8

  if trabaja == 1:
    descuento = descuento
  elif trabaja == 0:
    descuento = descuento*0.5
  else:
    'Edad no valida'

  tarifa_final = tarifa*descuento

  print('La tarifa final es:', tarifa_final, '€')
# Out:
# La tarifa final es: 100 €

# %%
# Objetivo: Establecer la tarifa anual para autobuses de Huesca.

tarifa = 5000
edad = int(input('edad: '))
trabaja = int(input('1 si trabajas. 0 si no trabajas: '))
estudia = int(input('1 si estudias. 0 si no estudias: '))
familianumerosa = int(input('1 si familia numerosa. 0 si no familia numerosa: '))
tarifafinal = 0

if(edad < 18 and trabaja == 1):
  tarifafinal = tarifa * 0.7
    
elif(edad < 18 and trabaja == 0):
  tarifafinal = tarifa * 0.5

elif(edad >= 18 and trabaja == 0):
  tarifafinal = tarifa * 0.85

elif(estudia == 1 and familianumerosa == 1):
  tarifafinal = tarifa * 0.50

elif(estudia == 1):
  tarifafinal = tarifa * 0.70

elif(familianumerosa == 1):
  tarifafinal = tarifa * 0.70


elif(estudia == 0 and trabaja == 0 and edad > 18):
  tarifafinal = tarifa * 2


else:
  tarifafinal = tarifa

print(tarifafinal)
# Out:
# edad: 18
# 1 si trabajas. 0 si no trabajas: 1
# 1 si estudias. 0 si no estudias: 0
# 1 si familia numerosa. 0 si no familia numerosa: 0
# 5000

# %%
# Objetivo: Establecer la tarifa anual para autobuses de Huesca, Ona 30/01/23
# poner un precio una tarifa la que queramos edad y si trabaja, condicionales descuentos segun edad o si trabaja o no trabaja
#Variables
tarifa =150
edad = int(input('Dime la edad del cliente...'))
trabaja = int(input('Dame 1 si trabajas. 0 en caso contrario.'))
tarifa_final = 0
 #Algoritmo
if(edad < 18 and trabaja == 0):
  tarifa_final = tarifa * 0.90
  print('Los niños tienen precio especial',tarifa_final )

elif(edad < 18 and trabaja == 1):
  tarifa_final = tarifa * 0.90
  print('Los niños tienen precio especial, si trabajan tambien',tarifa_final)

elif(edad > 18 and trabaja == 1):
  tarifa_final = tarifa * 1.2
  print('Los adultos trabajadores tienen un preciazo',tarifa_final)

elif(edad > 18 and trabaja == 0):
  tarifa_final = tarifa * 0.80
  print('Los adultos que no trabajan pagan menos',tarifa_final)

elif(edad == 18):
  tarifa_final = tarifa * 0.50
  print('si acabas de cumplir 18 años sientete como un niño al tener un precio especial,trabajes o no', tarifa_final)

else:
    tarifa_final = tarifa

print('Tu tarifa final es de ',tarifa_final)
# Out:
# Dime la edad del cliente...27
# Dame 1 si trabajas. 0 en caso contrario.9876543
# 150

# %%
#
#     V1
#

# Objetivo: Establecer la tarifa anual para autobuses de Huesca.

#Variables
tarifa = 100
edad = int(input('Dime la edad del cliente...'))
trabaja = int(input('Dame 1 si trabajas. 0 en caso contrario.'))
tarifa_final = 0

#Algoritmo
if(edad < 18 and trabaja == 1):
    tarifa_final = tarifa * 0.7
    
elif(edad < 18 and trabaja == 0):
    tarifa_final = tarifa * 0.5

elif(edad >= 18 and trabaja == 0):
    tarifa_final = tarifa * 0.85

else:
    tarifa_final = tarifa

print(tarifa_final)




#
#     V2
#


# Objetivo: Establecer la tarifa anual para Salamanca.

#Variables
tarifa = 100
edad = int(input('Dime la edad del cliente...'))
trabaja = int(input('Dame 1 si trabajas. 0 en caso contrario.'))
tarifa_final = 0

#Algoritmo
if(edad < 18): #Menor...
    if(trabaja == 1):
        tarifa_final = tarifa * 0.7
    else:
        tarifa_final = tarifa * 0.5
else: #Mayor...
    if(trabaja == 1):
        tarifa_final = tarifa
    else:
        tarifa_final = tarifa * 0.85
    

print(tarifa_final)

# %% [markdown]
# ## Bucles For

# %% [markdown]
# Imprimir todos los dígitos decimales, del 0 al 9, utilizando una repetición
# ```
# for x in range(10):
#     print(x)
# ```
#
# Factorial:
#
#
#
# Imprimir todos los números entre el 100 y el 199.
#
#
#
# ```
# for x in range(100,200):
#     print(x)
# ```
#
#
#
# Requerir al usuario que ingrese un número entero positivo e imprimir todos los números correlativos entre el ingresado por el usuario y uno menos del doble del mismo.
# ```
# n=int(input("Número: "))
# for x in range(n, n*2):
#     print(x)
# ```
#
# Solicitar al usuario que ingrese una frase y luego imprimir la cantidad de vocales que se encuentran en dicha frase.
# ```
# frase=input("Frase: ")
# cantidad=0
# for x in frase:
#     if x in "aeiou":
#         cantidad+=1
# print("Cantidad de vocales:", cantidad)
# ```

# %%
for x in range(10):
    print(x)

# %%
for x in range(100,200):
    print(x)

# %%
n=int(input("Número: "))
for x in range(n, n*2):
    print(x)

# %%
frase=input("Frase: ")
cantidad=0
for x in frase:
    if x in "aeiou":    # comprobación
        cantidad+=1
print("Cantidad de vocales:", cantidad)
# Out:
# Cantidad de vocales: 5
