# %% [markdown]
# **EDA**

# %% [markdown]
# Empezamos preguntándonos... “¿de qué se trata?”, patrones y distribuciones. Nos permitirá:
# -	Conocer los Datos y entenderlos
# -	Identificar patrones e incoherencias
# -	Fijarnos en los Outliers o valores atípicos e identificarlos
# -	NO se manipulan datos.
#
# Preguntas básicas:
# -	¿Cuántos registros hay?
# -	¿Son demasiado pocos?
# -	¿Son muchos y no tenemos capacidad (CPU+RAM) suficiente para procesarlo?
# -	¿Están todas las filas completas ó tenemos campos con valores nulos?
# -	En caso que haya demasiados nulos: ¿queda el resto de información inútil?
# -	¿Cuáles parecen ser features importantes? ¿Cuáles podemos descartar?
# -	¿Hay correlación entre features (características/campos/columnas)?

# %% [markdown]
# **TITULO**:
#
# European Funds dataset from Morningstar
#
# **FUENTE DE DATOS:**
# https://www.kaggle.com/datasets/stefanoleone992/european-funds-dataset-from-morningstar?select=Morningstar+-+European+ETFs.csv
#
# **DESCRIPCIÓN**
#
# The file contains 9,495 ETFs with general aspects (as Total Net Assets, management company and size), portfolio indicators (as cash, stocks, bonds, and sectors), returns (as year_to_date, 2020-11) and financial ratios (as price/earning, Treynor and Sharpe ratios, alpha, and beta).
#
# Additional data in terms of sustainability is also available.
#
# Data has been scraped from the publicly available website https://www.morningstar.co.uk.
#
# Datasets allow for multiple comparisons regarding portfolio restrictions to the indexes in ETFs. Datasets will be updated on a semi-annual or annual basis.
#
#
# ---
#
#
# **PREGUNTAS BÁSICAS:**
#
# *   Número de registros: 9495
# *   Número de columnas: 132
# *   Clave primaria: fund ticker code
# *   Existen campos nulos: sí
# *
#
#
#
# **TIPOS DE VARIABLES**
#
# 1.   Cualitativas
#
# > Nominales
# *   Ticker - Clave primaria
# *   ISIN
# *   Fund Name
# *   Invest_strategy
# *   Invest_manage
#
#
# > Ordinales
# *  Inception_Date
# *  Category
# *  Rating
# *  Analyst_rating
# *
# *  Dividend_frequency
# *  Fund_benchmark
# *  equity_style_score
# *  equity_style
# *  equity_size
# *  bond_interest_rate_sensitivity
# *  bond_credit_quality
#
# 2.   Cuantitativas
#
# > Discretas
# *  Risk_rating
# *  Performance_rating
#
# > Continuas
#
# price_prospective_earnings
# price_book_ratio
# price_sales_ratio
# price_cash_flow_ratio
# long_term_projected_earnings_growth	historical_earnings_growth
# sales_growth
# cash_flow_growth
# book_value_growth
# roa
# roe
# roic

# %% [markdown]
# CARGA DE LIBRERIAS (SEPARAR EN UNA CELDA)

# %%
#IMPORTAR LIBRERIAS
import pandas as pd  #ALIAS. Abreviaturas OFICIALES
import numpy as np
import matplotlib.pyplot as plt

#import seaborn as sns
import plotly as ply

# %% [markdown]
# CARGA DEL DATAFRAME (SEPARAR EN OTRA CELDA)

# %%
#tablaMSETF = pd.read_csv('/content/drive/MyDrive/CURSO BIG DATA/MODULO 4/Morningstar - European ETFs.csv') #Mirar siempre la DOC de las funciones

tablaMSETF = pd.read_csv('C:/Users/Usuario/OneDrive/Documentos/PROGRAMACION/Curso-Big-Data/MODULO 4 - Data Fundamentals con Python/EJERCICIOS/SESION 3/Morningstar - European ETFs.csv')

# %% [markdown]
# VISUALIZACIÓN DE LA TABLA
#
# Usar la función DISPLAY

# %%
print(type(tablaMSETF))
print(type('hola'))
print(tablaMSETF)
display(tablaMSETF)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'str'>
#           ticker          isin  \
# 0     0P00000C5S  CH0008899764
# 1     0P00000FYY  SE0000693293
# 2     0P00000GCE  DE000A0H08N1
# 3     0P00000GF2  DE0006289465
# 4     0P00000GKU  IE0032523478
# ...          ...           ...
# 9490  0P0001K8E2  LU2099288503
# 9491  0P0001K9DU  LU1220245556
# 9492  0P0001K9DV  LU1923627332
# 9493  0P0001K9DW  LU1650492256
# 9494  0P0001KJPH  DE000A1ZK3W9
#
#                                               fund_name inception_date  \
# 0                                 iShares SMI® ETF (CH)     1999-10-06
# 1                                 XACT OMXS30 UCITS ETF     2000-10-30
# 2     iShares STOXX Europe 600 Personal & Household ...     2002-07-08
# 3     iShares eb.rexx® Government Germany UCITS ETF ...     2003-02-04
# 4     iShares € Corp Bond Large Cap UCITS ETF EUR (D...     2003-03-17
# ...                                                 ...            ...
# ...

# %%
print(tablaMSETF.columns) #columnas de la tabla
print(tablaMSETF.index)   #índices

tablaMSETF.info() #información agregada de la tabla
# Out:
# Index(['ticker', 'isin', 'fund_name', 'inception_date', 'category', 'rating',
#        'analyst_rating', 'risk_rating', 'performance_rating',
#        'investment_strategy',
#        ...
#        'fund_return_2016_q4', 'fund_return_2016_q3', 'fund_return_2016_q2',
#        'fund_return_2016_q1', 'fund_return_2015_q4', 'fund_return_2015_q3',
#        'fund_return_2015_q2', 'fund_return_2015_q1', 'quarters_up',
#        'quarters_down'],
#       dtype='object', length=132)
# RangeIndex(start=0, stop=9495, step=1)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9495 entries, 0 to 9494
# Columns: 132 entries, ticker to quarters_down
# dtypes: float64(108), int64(2), object(22)
# memory usage: 9.6+ MB

# %% [markdown]
# https://datacarpentry.org/python-ecology-lesson-es/04-data-types-and-format/
#
# **El método astype()**
#
# Los objetos de Pandas, tanto las Series como los DataFrame, poseen el método astype() que tiene las siguientes propiedades
#
# obj.astype(dtype, copy=True, errors='raise')
# en donde los parámetros son:
#
# **dtype**: el tipo de dato de Python al que se desea convertir todos los valores del objeto Series o DataFrame
#
# **copy**: indica si se el método retorna una copia del objeto con las modificaciones, opción por defecto, o el objeto original modificado.
#
# **errors**: la forma en la que se manejan los posibles errores. Existen dos opciones:
# * raise en el caso de que se produzca un error se lanzará una excepción y se parará la ejecución del código
# * ignore el error se ignora y se devuelve el valor original.
#
# EJEMPLO:
#
# nombre_dataframe['campo1'] = nombre_dataframe['campo1'].astype('tipo_destino')
#
# **TIPOS**
# - object --> string
# - int32 o int64 --> int
# - float32 o float64 --> float
# -
# - category
# - datetime64

# %%
import string

#DECLARAMOS LA TABLA users
users = {'first_name': ['Montgomery', 'Dagmar', 'Reeba', 'Shalom', 'Broddy', 'Aurelia'],
         'last_name': ['Humes', 'Elstow', 'Wattisham', 'Alen', 'Keningham', 'Brechin'],
         'age': [27, 41, 29, 29, 55, 67],
         'gender': ['Male', 'Female', 'Female', 'Male', 'Male', 'Female'], 
         'sales': [92.15, 65.43, 56, 59.55, 26.30, 65.23],
         'bdate': ['20000102','20010203','20020304','20030405','20040607','20050809']}
df = pd.DataFrame(users)

print('FORMATO INICIAL\n',df.dtypes) #muestra las columnas y sus tipos de datos

df['first_name'] = df['first_name'].astype('string') #cambio columna a columna

#FORMATO GENERAL
df = df.astype({'first_name': 'string', 
                'last_name' : 'string',
                'age' : 'int',
                'gender' : 'category',
                'sales' : 'float',
                'bdate' : 'datetime64'})

print('\nFORMATO FINAL\n',df.dtypes)

display(df)

#TRABAJANDO CON 0 y NULOS
print(len(df[df.age > 0])) #muestra cuántos elementos dentro de age son mayores que 0

print(round(df['age'].mean(),2)) #La función mean() devuelve la media aritmética de los datos de una muestra o población. Esta media se calcula sumando todos los valores y después el resultado de la suma se divide entre el número de elementos.

df.to_csv('C:/Users/Usuario/OneDrive/Documentos/PROGRAMACION/Curso-Big-Data/MODULO 4 - Data Fundamentals con Python/EJERCICIOS/SESION 3/users.csv', index=False)
# Out:
# FORMATO INICIAL
#  first_name     object
# last_name      object
# age             int64
# gender         object
# sales         float64
# bdate          object
# dtype: object
#
# FORMATO FINAL
#  first_name            string
# last_name             string
# age                    int32
# gender              category
# sales                float64
# bdate         datetime64[ns]
# dtype: object
#    first_name  last_name  age  gender  sales      bdate
# 0  Montgomery      Humes   27    Male  92.15 2000-01-02
# 1      Dagmar     Elstow   41  Female  65.43 2001-02-03
# 2       Reeba  Wattisham   29  Female  56.00 2002-03-04
# 3      Shalom       Alen   29    Male  59.55 2003-04-05
# 4      Broddy  Keningham   55    Male  26.30 2004-06-07
# 5     Aurelia    Brechin   67  Female  65.23 2005-08-09
# 6
# 41.33
